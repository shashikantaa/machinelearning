# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
import seaborn as sns
from sklearn.tree import export_graphviz,plot_tree

# %%
df=pd.read_csv(r"D:\Document\DATASETS-16AUG2023\mtcars.csv")

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2      4     1
# 3      3     1
# 4      3     2
# 5      3     1
# 6      3     4
# 7      4     2
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17     4     1
# 18     4     2
# 19     4     1
# 20     3     1
# 21     3     2
# 22     3     2
# 23     3     4
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
df.isnull().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
df=df.drop('model', axis=1)
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# 13  15.2    8  275.8  180  3.07  3.780  18.00   0   0     3     3
# 14  10.4    8  472.0  205  2.93  5.250  17.98   0   0     3     4
# 15  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3     4
# 16  14.7    8  440.0  230  3.23  5.345  17.42   0   0     3     4
# 17  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4     1
# 18  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4     2
# 19  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4     1
# 20  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3     1
# 21  15.5    8  318.0  150  2.76  3.520  16.87   0   0     3     2
# 22  15.2    8  304.0  150  3.15  3.435  17.30   0   0     3     2
# 23  13.3    8  350.0  245  3.73  3.840  15.41   0   0     3     4
# 24  19.2    8  400.0  175  3.08  3.845  17.05   0   0     3     2
# 25  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4     1
# 26  26.0    4  120.3   91  4.43  2.140  16.70   0   1     5     2
# 27  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5     2
# 28  15.8    8  351.0  264  4.22  3.170  14.50   0   1     5     4
# 29  19.7    6  145.0  175  3.62  2.770  15.50   0   1     5     6
# 30  15.0    8  301.0  335  3.54  3.570  14.60   0   1     5     8
# 31  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4     2

# %%
x=df.drop('mpg',axis=1)
y=df['mpg']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=30,shuffle=True)

# %%
regressor=DecisionTreeRegressor()

# %%
regressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=regressor.predict(x_test)

# %%
y_pred
# Out:
# array([17.3, 19.2, 19.2, 30.4, 24.4, 32.4, 32.4])

# %%
export_graphviz(regressor,out_file='tree.dot',feature_names=x.columns)
plot_tree(regressor)
# Out:
# [Text(0.335, 0.9375, 'X[4] <= 2.26\nsquared_error = 34.51\nsamples = 25\nvalue = 19.536'),
#  Text(0.12, 0.8125, 'X[2] <= 89.5\nsquared_error = 2.056\nsamples = 3\nvalue = 32.233'),
#  Text(0.08, 0.6875, 'X[5] <= 19.685\nsquared_error = 0.563\nsamples = 2\nvalue = 33.15'),
#  Text(0.04, 0.5625, 'squared_error = 0.0\nsamples = 1\nvalue = 32.4'),
#  Text(0.12, 0.5625, 'squared_error = 0.0\nsamples = 1\nvalue = 33.9'),
#  Text(0.16, 0.6875, 'squared_error = -0.0\nsamples = 1\nvalue = 30.4'),
#  Text(0.55, 0.8125, 'X[2] <= 177.5\nsquared_error = 13.953\nsamples = 22\nvalue = 17.805'),
#  Text(0.3, 0.6875, 'X[4] <= 3.327\nsquared_error = 4.702\nsamples = 13\nvalue = 20.3'),
#  Text(0.2, 0.5625, 'X[2] <= 95.0\nsquared_error = 1.71\nsamples = 8\nvalue = 21.65'),
#  Text(0.12, 0.4375, 'X[1] <= 127.35\nsquared_error = 0.64\nsamples = 2\nvalue = 23.6'),
#  Text(0.08, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 22.8'),
#  Text(0.16, 0.3125, 'squared_error = -0.0\nsamples = 1\nvalue = 24.4'),
#  Text(0.28, 0.4375, 'X[2] <= 142.5\nsquared_error = 0.377\nsamples = 6\nvalue = 21.0'),
#  Text(0.24, 0.3125, 'X[9] <= 3.0\nsquared_error = 0.046\nsamples = 5\nvalue = 21.26'),
#  Text(0.16, 0.1875, 'X[4] <= 2.622\nsquared_error = 0.002\nsamples = 3\nvalue = 21.433'),
#  Text(0.12, 0.0625, 'squared_error = 0.0\nsamples = 1\nvalue = 21.5'),
#  Text(0.2, 0.0625, 'squared_error = 0.0\nsamples = 2\nvalue = 21.4'),
#  Text(0.32, 0.1875, 'X[4] <= 2.747\nsquared_error = 0.0\nsamples = 2\nvalue = 21.0'),
#  Text(0.28, 0.0625, 'squared_error = 0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.36, 0.0625, 'squared_error = 0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.32, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 19.7'),
#  Text(0.4, 0.5625, 'X[5] <= 16.945\nsquared_error = 1.906\nsamples = 5\nvalue = 18.14'),
#  Text(0.36, 0.4375, 'squared_error = 0.0\nsamples = 1\nvalue = 15.5'),
#  Text(0.44, 0.4375, 'X[3] <= 2.92\nsquared_error = 0.205\nsamples = 4\nvalue = 18.8'),
#  Text(0.4, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 18.1'),
#  Text(0.48, 0.3125, 'X[5] <= 17.035\nsquared_error = 0.056\nsamples = 3\nvalue = 19.033'),
#  Text(0.44, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 18.7'),
#  Text(0.52, 0.1875, 'X[9] <= 3.0\nsquared_error = 0.0\nsamples = 2\nvalue = 19.2'),
#  Text(0.48, 0.0625, 'squared_error = 0.0\nsamples = 1\nvalue = 19.2'),
#  Text(0.56, 0.0625, 'squared_error = 0.0\nsamples = 1\nvalue = 19.2'),
#  Text(0.8, 0.6875, 'X[1] <= 450.0\nsquared_error = 5.329\nsamples = 9\nvalue = 14.2'),
#  Text(0.76, 0.5625, 'X[1] <= 312.9\nsquared_error = 1.547\nsamples = 7\nvalue = 15.286'),
#  Text(0.68, 0.4375, 'X[5] <= 17.8\nsquared_error = 0.74\nsamples = 3\nvalue = 16.3'),
#  Text(0.64, 0.3125, 'X[4] <= 3.9\nsquared_error = 0.202\nsamples = 2\nvalue = 16.85'),
#  Text(0.6, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 17.3'),
#  Text(0.68, 0.1875, 'squared_error = -0.0\nsamples = 1\nvalue = 16.4'),
#  Text(0.72, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 15.2'),
#  Text(0.84, 0.4375, 'X[5] <= 14.955\nsquared_error = 0.802\nsamples = 4\nvalue = 14.525'),
#  Text(0.8, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 15.8'),
#  Text(0.88, 0.3125, 'X[1] <= 355.0\nsquared_error = 0.347\nsamples = 3\nvalue = 14.1'),
#  Text(0.84, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 13.3'),
#  Text(0.92, 0.1875, 'X[2] <= 237.5\nsquared_error = 0.04\nsamples = 2\nvalue = 14.5'),
#  Text(0.88, 0.0625, 'squared_error = 0.0\nsamples = 1\nvalue = 14.7'),
#  Text(0.96, 0.0625, 'squared_error = 0.0\nsamples = 1\nvalue = 14.3'),
#  Text(0.84, 0.5625, 'squared_error = -0.0\nsamples = 2\nvalue = 10.4')]
